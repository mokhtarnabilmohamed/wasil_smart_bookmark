# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/u/0/folders/1MKwd6v3B8hT3oCvw2MXBtCTNfjGhG4OC
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/wasil_smart_bookmark'
# /content

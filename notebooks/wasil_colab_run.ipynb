# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/wasil_smart_bookmark
# Out:
# /content/drive/MyDrive/wasil_smart_bookmark

# %%
# !rm -rf /content/wasil_smart_bookmark

# %%
# !git clone https://github.com/mokhtarnabilmohamed/wasil_smart_bookmark.git /content/wasil_smart_bookmark
# Out:
# Cloning into '/content/wasil_smart_bookmark'...
# remote: Enumerating objects: 28, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 28 (delta 1), reused 28 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (28/28), 17.85 MiB | 21.97 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
# %cd /content/wasil_smart_bookmark
# Out:
# /content/wasil_smart_bookmark

# %%
# !ls
# Out:
# dataset  outputs  README.md  requirements.txt  src

# %%
# !pip install -r requirements.txt

# %%
# !pip install transformers accelerate timm

# %%
import torch

print("CUDA available:", torch.cuda.is_available())
print("Device:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU")
# Out:
# CUDA available: True
# Device: Tesla T4

# %%
DATA_ROOT = "/content/drive/MyDrive/wasil_smart_bookmark"
PAGES_DIR = f"{DATA_ROOT}/dataset/pages"
STRIPS_DIR = f"{DATA_ROOT}/dataset/strips_30mm"
METADATA_PATH = f"{DATA_ROOT}/dataset/metadata.csv"

FEATURES_DIR = f"{DATA_ROOT}/outputs/features_dit"
MODELS_DIR = f"{DATA_ROOT}/outputs/models_dit"
RESULTS_DIR = f"{DATA_ROOT}/outputs_dit"

# %%
# !ls "/content/drive/MyDrive/wasil_smart_bookmark/dataset/pages" | head
# Out:
# 15_MusahffMedinaAdie1447-page-00005.jpg
# 15_MusahffMedinaAdie1447-page-00006.jpg
# 15_MusahffMedinaAdie1447-page-00007.jpg
# 15_MusahffMedinaAdie1447-page-00008.jpg
# 15_MusahffMedinaAdie1447-page-00009.jpg
# 15_MusahffMedinaAdie1447-page-00010.jpg
# 15_MusahffMedinaAdie1447-page-00011.jpg
# 15_MusahffMedinaAdie1447-page-00012.jpg
# 15_MusahffMedinaAdie1447-page-00013.jpg
# 15_MusahffMedinaAdie1447-page-00014.jpg

# %%
# !python src/generate_strips.py \
  --input "/content/drive/MyDrive/wasil_smart_bookmark/dataset/pages" \
  --output "/content/drive/MyDrive/wasil_smart_bookmark/dataset/strips_30mm"
# Out:
# Generating strips: 100% 604/604 [21:40<00:00,  2.15s/it]
# Generated 12080 strips and saved to /content/drive/MyDrive/wasil_smart_bookmark/dataset/strips_30mm

# %%
# !ls "/content/drive/MyDrive/wasil_smart_bookmark/dataset/strips_30mm" | head
# !ls "/content/drive/MyDrive/wasil_smart_bookmark/dataset"
# Out:
# desktop.ini
# mushaf_15_MusahffMedinaAdie1447-page-00005_strip_000_30mm.png
# mushaf_15_MusahffMedinaAdie1447-page-00005_strip_001_30mm.png
# mushaf_15_MusahffMedinaAdie1447-page-00005_strip_002_30mm.png
# mushaf_15_MusahffMedinaAdie1447-page-00005_strip_003_30mm.png
# mushaf_15_MusahffMedinaAdie1447-page-00005_strip_004_30mm.png
# mushaf_15_MusahffMedinaAdie1447-page-00005_strip_005_30mm.png
# mushaf_15_MusahffMedinaAdie1447-page-00005_strip_006_30mm.png
# mushaf_15_MusahffMedinaAdie1447-page-00005_strip_007_30mm.png
# mushaf_15_MusahffMedinaAdie1447-page-00005_strip_008_30mm.png
# desktop.ini  metadata.csv  pages  strips_30mm

# %%
# !python src/extract_features_dit.py \
  --metadata "/content/drive/MyDrive/wasil_smart_bookmark/dataset/metadata.csv" \
  --strips_dir "/content/drive/MyDrive/wasil_smart_bookmark/dataset/strips_30mm" \
  --output_dir "/content/drive/MyDrive/wasil_smart_bookmark/outputs/features_dit" \
  --model_name "microsoft/dit-base" \
  --pca_components 256
# Out:
# python3: can't open file '/content/wasil_smart_bookmark/src/extract_features_dit.py': [Errno 2] No such file or directory

# %%
# !rm -rf /content/wasil_smart_bookmark
# !git clone https://github.com/mokhtarnabilmohamed/wasil_smart_bookmark.git /content/wasil_smart_bookmark
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# Cloning into '/content/wasil_smart_bookmark'...
# fatal: Unable to read current working directory: No such file or directory

# %%
# !rm -rf /content/wasil_smart_bookmark
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory

# %%
# !ls /content
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# drive  sample_data

# %%
# !git clone https://github.com/mokhtarnabilmohamed/wasil_smart_bookmark.git /content/wasil_smart_bookmark
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# Cloning into '/content/wasil_smart_bookmark'...
# fatal: Unable to read current working directory: No such file or directory

# %%
Runtime / Kernel → Restart Runtime
# Out:
#   File "/tmp/ipykernel_3243/2969826635.py", line 1
#     Runtime / Kernel → Restart Runtime
#                      ^
# SyntaxError: invalid character '→' (U+2192)

# %%
Restart Kernel
# Out:
#   File "/tmp/ipykernel_3243/757113262.py", line 1
#     Restart Kernel
#             ^
# SyntaxError: invalid syntax

# %%
# %cd /content
# Out:
# /content

# %%
# !pwd
# !ls
# Out:
# /content
# drive  sample_data

# %%
# !git clone https://github.com/mokhtarnabilmohamed/wasil_smart_bookmark.git /content/wasil_smart_bookmark
# Out:
# Cloning into '/content/wasil_smart_bookmark'...
# remote: Enumerating objects: 40, done.
# remote: Counting objects: 100% (40/40), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 40 (delta 4), reused 40 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (40/40), 17.85 MiB | 29.44 MiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %%
# !ls
# !ls wasil_smart_bookmark/src/
# Out:
# drive  sample_data  wasil_smart_bookmark
# create_demo_data.py	 extract_features.py  preprocess.py
# evaluate.py		 generate_strips.py   train_classifiers.py
# extract_features_dit.py  plot_results.py      utils.py

# %%
# !python wasil_smart_bookmark/src/extract_features_dit.py \
  --metadata "/content/drive/MyDrive/wasil_smart_bookmark/dataset/metadata.csv" \
  --strips_dir "/content/drive/MyDrive/wasil_smart_bookmark/dataset/strips_30mm" \
  --output_dir "/content/drive/MyDrive/wasil_smart_bookmark/outputs/features_dit" \
  --model_name "microsoft/dit-base" \
  --pca_components 256
# Out:
# Using device: cuda
# preprocessor_config.json: 100% 302/302 [00:00<00:00, 1.39MB/s]
# /usr/local/lib/python3.12/dist-packages/transformers/image_processing_base.py:370: UserWarning: The following named arguments are not valid for `BeitImageProcessor.__init__` and were ignored: 'feature_extractor_type', 'reduce_labels'
#   image_processor = cls(**image_processor_dict)
# config.json: 1.03kB [00:00, 3.79MB/s]
# ...
# pytorch_model.bin: 100% 369M/369M [00:03<00:00, 113MB/s]
# Loading weights: 100% 209/209 [00:00<00:00, 1427.70it/s, Materializing param=encoder.layer.11.output.dense.weight]
# BeitModel LOAD REPORT from: microsoft/dit-base
# Key                     | Status     |
# ------------------------+------------+-
# layernorm.bias          | UNEXPECTED |
# layernorm.weight        | UNEXPECTED |
# lm_head.bias            | UNEXPECTED |
# lm_head.weight          | UNEXPECTED |
# pooler.layernorm.bias   | MISSING    |
# pooler.layernorm.weight | MISSING    |
#
# Notes:
# ...

# %%
# !python -c "import sys; sys.path.append('wasil_smart_bookmark/src'); from train_classifiers import train_and_evaluate; train_and_evaluate('/content/drive/MyDrive/wasil_smart_bookmark/outputs/features_dit/features_pca.npy', '/content/drive/MyDrive/wasil_smart_bookmark/outputs/features_dit/labels.csv', '/content/drive/MyDrive/wasil_smart_bookmark/outputs/models_dit')"
# Out:
# Training SVM...
# SVM Accuracy: 0.7219
# Training LogReg...
# LogReg Accuracy: 0.6611
# Training RandomForest...
# RandomForest Accuracy: 0.2688
